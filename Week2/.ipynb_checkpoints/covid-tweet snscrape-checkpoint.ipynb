# %%
#conda install -c conda-forge tweepy
#or
#pip install tweepy

# %% [markdown]
# snscrape
#
# Ref: https://github.com/JustAnotherArchivist/snscrape

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %% [markdown]
# Scraping a specific Twitter user’s tweets
#
# Let's use this handle: @govsingapore
#
# Using the code, we can scrape 100 tweets from Twitter user @govsingapore
# We then pulled the DateTime, tweet id, text, and username attributes from the tweet objects.

# %%
# Creating list to append tweet data 
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
handle = 'govsingapore'

# declare a username 
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('from:' + handle).get_items()): 
    if i > 100: #number of tweets you want to scrape
        break
        
    #declare the attributes to be returned
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
    
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
# Out:
# C:\Users\hannah.kim\AppData\Local\Temp\ipykernel_1364\3477890101.py:13: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# %%
tweets_df1
# Out:
#                     Datetime             Tweet Id  \
# 0  2023-02-11 06:59:35+00:00  1624302109742215173
# 1  2023-02-11 06:59:22+00:00  1624302054742306816
# 2  2023-02-10 06:13:55+00:00  1623928230595170304
# 3  2023-02-09 08:56:00+00:00  1623606632130449408
# 4  2023-02-08 10:30:00+00:00  1623267899849969664
# 5  2023-02-07 02:34:04+00:00  1622785738260590592
# 6  2023-02-07 02:33:50+00:00  1622785680807194625
# 7  2023-02-03 10:03:00+00:00  1621449163392032768
# 8  2023-02-01 10:00:42+00:00  1620723809077833729
# 9  2023-01-25 06:42:52+00:00  1618137310012538883
# 10 2023-01-25 06:42:26+00:00  1618137201350676481
#
#                                                  Text      Username
# 0                             https://t.co/0ubZojtOTx  govsingapore
# 1   HDB provides significant subsidies and grants,...  govsingapore
# 2   #ForwardSG Minister @DesmondTSLee joins @Hossa...  govsingapore
# 3   📣 Singapore’s COVID-19 situation has remained ...  govsingapore
# ...

# %% [markdown]
# Scraping tweets from a text search query
#
# Using the code below, we are scraping 5000 tweets between:  2022-01-01 until:2023-01-31,
# with the keywords 'covid-19'.
#
# I then pulled attributes DateTime, tweet id, text, and username from the tweet objects.

# %%
# Creating list to append tweet data to
tweets_list2 = []

# search terms
search_terms = 'covid-19'

# Using TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(search_terms + ' since:2022-01-01 until:2023-01-31').get_items()):
    if i > 5000:
        break
    #declare the attributes to be returned
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
# Out:
# C:\Users\hannah.kim\AppData\Local\Temp\ipykernel_1364\61152983.py:12: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# %%
tweets_df2
# Out:
#                       Datetime             Tweet Id  \
# 0    2023-01-30 23:59:58+00:00  1620210242851328001
# 1    2023-01-30 23:59:57+00:00  1620210240246681602
# 2    2023-01-30 23:59:52+00:00  1620210217790365698
# 3    2023-01-30 23:59:48+00:00  1620210199201185792
# 4    2023-01-30 23:59:46+00:00  1620210193807331331
# ...                        ...                  ...
# 4996 2023-01-30 20:21:44+00:00  1620155321699434496
# 4997 2023-01-30 20:21:36+00:00  1620155288560214016
# 4998 2023-01-30 20:21:29+00:00  1620155259342700544
# 4999 2023-01-30 20:21:28+00:00  1620155253332271106
# 5000 2023-01-30 20:21:26+00:00  1620155246210162701
#
#                                                    Text        Username
# 0     @borghi_claudio Claudietto, non è che se ti me...     Monia_Podda
# 1     @CrossedKom Waalaikummussalam kom! Stay safe, ...       lampuapam
# 2     The Day 1042 COVID-19 Report of India || ABC L...         abclive
# ...

# %%
tweets_df2.to_csv('covid_tweets.csv', index=False, encoding='utf-8')

# %%
testdf = pd.read_csv('covid_tweets.csv')

# %%
testdf
# Out:
#                        Datetime             Tweet Id  \
# 0     2023-01-30 23:59:58+00:00  1620210242851328001
# 1     2023-01-30 23:59:57+00:00  1620210240246681602
# 2     2023-01-30 23:59:52+00:00  1620210217790365698
# 3     2023-01-30 23:59:48+00:00  1620210199201185792
# 4     2023-01-30 23:59:46+00:00  1620210193807331331
# ...                         ...                  ...
# 4996  2023-01-30 20:21:44+00:00  1620155321699434496
# 4997  2023-01-30 20:21:36+00:00  1620155288560214016
# 4998  2023-01-30 20:21:29+00:00  1620155259342700544
# 4999  2023-01-30 20:21:28+00:00  1620155253332271106
# 5000  2023-01-30 20:21:26+00:00  1620155246210162701
#
#                                                    Text        Username
# 0     @borghi_claudio Claudietto, non è che se ti me...     Monia_Podda
# 1     @CrossedKom Waalaikummussalam kom! Stay safe, ...       lampuapam
# 2     The Day 1042 COVID-19 Report of India || ABC L...         abclive
# ...
