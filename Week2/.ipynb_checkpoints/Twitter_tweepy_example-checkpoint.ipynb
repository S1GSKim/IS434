# %%
#conda install -c conda-forge tweepy
#or
#pip install tweepy

# %% [markdown]
# tweepy
#
# Official documentation: https://docs.tweepy.org/en/stable/
#
# Ref: https://dev.to/twitterdev/a-comprehensive-guide-for-using-the-twitter-api-v2-using-tweepy-in-python-15d9

# %%
import tweepy
import datetime
import pandas as pd
import json
import requests

# %%
# Update this variable with YOUR OWN Twitter Bearer Token
BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAAFcTlQEAAAAAlrR98XH6xOotQPc1hX96e8Ys7Dw%3DQuhCVtpzoGhrXqwMKXnJ01gjDYHolYqJ8nO4kxV8vMDvlJ9fEs'

client = tweepy.Client(bearer_token=BEARER_TOKEN, return_type=requests.Response)

# %%
'''
Searching for Tweets from the last 7 days

We can use the search_recent_tweets function available in Tweepy.
You will have to pass it a search query to specify the data that you are looking for.

Below, we will search for for Tweets from the last days from the 
Twitter handle realDonaldTrump and we are excluding retweets using -is:retweet.

By default, a request returns 10 Tweets.
If you want more than 10 Tweets per request, you can specify that using the max_results parameter.
The maximum Tweets per request is 100.
'''
# Replace with your own search query
handle = 'elonmusk'
query = 'from:' + handle + ' -is:retweet'

tweets1 = client.search_recent_tweets(
            query=query,
            tweet_fields=['context_annotations', 'created_at'],
            max_results=100)

# %%
'''
Convert to pandas Dataframe
'''

# Save data as dictionary
tweets_dict1 = tweets1.json()

# Extract "data" value from dictionary
tweets_data1 = tweets_dict1['data'] 

# Transform to pandas Dataframe
df1 = pd.json_normalize(tweets_data1)

df1
# Out:
#                                                  text edit_history_tweet_ids  \
# 0   @BBCBreaking Government data has far more late...  [1615259844067614721]
# 1   @ImMeme0 Is it even possible to parody their t...  [1615252150145417219]
# 2   @MirrorinSpace @Brookstone23 @realchrisrufo @w...  [1615237025715884032]
# 3   @paulg Looking at the comments, this social ne...  [1615231440429682688]
# 4                               @weirdterrifying Nice  [1615221493729988609]
# ..                                                ...                    ...
# 94  @Snowden Most people have no idea that Reality...  [1613425104872177665]
# 95  @TheRabbitHole84 @WallStreetSilv Maybe we shou...  [1613417131563167746]
# 96  @Tesmanian_com Starlink in aircraft feels the ...  [1613416693283553280]
# 97  @WallStreetSilv Demolition Man movie is becomi...  [1613353227633950721]
# 98          @ShellenbergerMD Constitutional violation  [1613343181378301952]
#
#                                   context_annotations  \
# 0   [{'domain': {'id': '46', 'name': 'Business Tax...
# 1   [{'domain': {'id': '46', 'name': 'Business Tax...
# 2   [{'domain': {'id': '46', 'name': 'Business Tax...
# 3   [{'domain': {'id': '46', 'name': 'Business Tax...
# 4   [{'domain': {'id': '46', 'name': 'Business Tax...
# ..                                                ...
# 94  [{'domain': {'id': '10', 'name': 'Person', 'de...
# 95  [{'domain': {'id': '46', 'name': 'Business Tax...
# 96  [{'domain': {'id': '46', 'name': 'Business Tax...
# 97  [{'domain': {'id': '46', 'name': 'Business Tax...
# 98  [{'domain': {'id': '46', 'name': 'Business Tax...
#
#                   created_at                   id
# 0   2023-01-17T08:08:51.000Z  1615259844067614721
# 1   2023-01-17T07:38:17.000Z  1615252150145417219
# 2   2023-01-17T06:38:11.000Z  1615237025715884032
# 3   2023-01-17T06:15:59.000Z  1615231440429682688
# 4   2023-01-17T05:36:28.000Z  1615221493729988609
# ..                       ...                  ...
# 94  2023-01-12T06:38:15.000Z  1613425104872177665
# 95  2023-01-12T06:06:34.000Z  1613417131563167746
# 96  2023-01-12T06:04:50.000Z  1613416693283553280
# 97  2023-01-12T01:52:38.000Z  1613353227633950721
# 98  2023-01-12T01:12:43.000Z  1613343181378301952
#
# [99 rows x 5 columns]

# %%
'''
If you want to get Tweets for a specific time-period, you can specify the time-period
using the start_time and end_time parameters, as shown in the example below:
'''

# Replace with time period of your choice
start_time = '2023-01-15T00:00:00Z'

# Replace with time period of your choice
end_time = '2023-01-17T00:00:00Z'


# Replace with your own search query
handle = 'elonmusk'
query = 'from:' + handle + ' -is:retweet'

tweets2 = client.search_recent_tweets(
            query=query,
            tweet_fields=['context_annotations', 'created_at'],
            start_time=start_time,
            end_time=end_time,
            max_results=100)

'''
Convert to pandas Dataframe
'''

tweets2.json()
# Out:
# {'data': [{'edit_history_tweet_ids': ['1615110825353838592'],
#    'context_annotations': [{'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '1549015486666420224', 'name': 'Scott Adams'}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '58',
#       'name': 'Entertainment Personality',
#       'description': 'An entertainment personality in the world, like Anderson Cooper or Miranda Sings'},
#      'entity': {'id': '1549015486666420224', 'name': 'Scott Adams'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1491172670917931008',
#       'name': 'Comic artists & writers'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1549015486666420224', 'name': 'Scott Adams'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1615110825353838592',
#    'text': '@ScottAdamsSays He’s right',
#    'created_at': '2023-01-16T22:16:42.000Z'},
#   {'edit_history_tweet_ids': ['1615078289475002368'],
#    'context_annotations': [{'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '1158770155557511168', 'name': 'Scott Manley'}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '120',
#       'name': 'Digital Creator',
#       'description': 'Influencers who create content on digital platforms'},
#      'entity': {'id': '1158770155557511168', 'name': 'Scott Manley'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '839543456678596608', 'name': 'Digital creators'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1158770155557511168', 'name': 'Scott Manley'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1615078289475002368',
#    'text': '@DJSnM @ThePrimalDino Center core moving too fast return. Falcon Heavy is a 3 (or 2.5) stage rocket, but full &amp; rapid reusability on Earth demand a 2 stage rocket.\n\n1st stage returns to launch site immediately via boostback &amp; 2nd stage orbits until ground track passes back over launch site to return.',
#    'created_at': '2023-01-16T20:07:25.000Z'},
#   {'edit_history_tweet_ids': ['1615075535763419137'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1615075535763419137',
#    'text': '@appuntito160 People on the right should see more “left wing” stuff and people on the left should see more “right wing” stuff.\n\nBut you can just block it if you want to stay in an echo chamber.',
#    'created_at': '2023-01-16T19:56:29.000Z'},
#   {'edit_history_tweet_ids': ['1615070479278313472'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1615070479278313472',
#    'text': '@DavidSacks The censorship tools were created to deal with scams &amp; spam, but then were turned to political purposes.\n\nThose who favor censorship should remember that it is only a matter of time before censorship turns on you.\n\nThere will always be some censorship, but less is better.',
#    'created_at': '2023-01-16T19:36:23.000Z'},
#   {'edit_history_tweet_ids': ['1615067712409202689'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1615067712409202689',
#    'text': '@stats_feed Exactly. Money is actually a set of heterogeneous databases with vast amounts of legacy code still using COBOL on mainframes in batch mode.',
#    'created_at': '2023-01-16T19:25:23.000Z'},
#   {'edit_history_tweet_ids': ['1615064194889691138'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '47',
#       'name': 'Brand',
#       'description': 'Brands and Companies'},
#      'entity': {'id': '1168530588535386112', 'name': 'Zerohedge'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1615064194889691138',
#    'text': '@DavidSacks @zerohedge Zerohedge can be jerks at times, but they did nothing warranting suspension',
#    'created_at': '2023-01-16T19:11:25.000Z'},
#   {'edit_history_tweet_ids': ['1615060236842434561'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1615060236842434561',
#    'text': '@stats_feed Sea water contains enough of every element to support &gt;10X current civilizational needs',
#    'created_at': '2023-01-16T18:55:41.000Z'},
#   {'edit_history_tweet_ids': ['1615042395980300289'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '47',
#       'name': 'Brand',
#       'description': 'Brands and Companies'},
#      'entity': {'id': '1534290336670883840', 'name': '4chan'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1534290336670883840', 'name': '4chan'}},
#     {'domain': {'id': '165',
#       'name': 'Technology',
#       'description': 'for individual and types of technology, e.g., food technology, 3D printing'},
#      'entity': {'id': '1196446161223028736', 'name': 'Social media'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1615042395980300289',
#    'text': '@ShellenbergerMD @wef @Davos There should be a game show: “4Chan or Davos, who said it?”',
#    'created_at': '2023-01-16T17:44:47.000Z'},
#   {'edit_history_tweet_ids': ['1614852938375258112'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614852938375258112',
#    'text': '@stillgray Do you actually know where your money is going?',
#    'created_at': '2023-01-16T05:11:57.000Z'},
#   {'edit_history_tweet_ids': ['1614851530016067586'],
#    'context_annotations': [{'domain': {'id': '45',
#       'name': 'Brand Vertical',
#       'description': 'Top level entities that describe a Brands industry'},
#      'entity': {'id': '781974597310615553', 'name': 'Entertainment'}},
#     {'domain': {'id': '30',
#       'name': 'Entities [Entity Service]',
#       'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'},
#      'entity': {'id': '781974597105094656',
#       'name': 'TV/Movies Related - Entertainment'}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '47',
#       'name': 'Brand',
#       'description': 'Brands and Companies'},
#      'entity': {'id': '1065659570578612224',
#       'name': 'BBC',
#       'description': 'BBC'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1065659570578612224',
#       'name': 'BBC',
#       'description': 'BBC'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614851530016067586',
#    'text': 'Kudos to the BBC for self-labelling its state affiliation',
#    'created_at': '2023-01-16T05:06:21.000Z'},
#   {'edit_history_tweet_ids': ['1614850335889305603'],
#    'context_annotations': [{'domain': {'id': '45',
#       'name': 'Brand Vertical',
#       'description': 'Top level entities that describe a Brands industry'},
#      'entity': {'id': '781974597310615553', 'name': 'Entertainment'}},
#     {'domain': {'id': '30',
#       'name': 'Entities [Entity Service]',
#       'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'},
#      'entity': {'id': '781974597105094656',
#       'name': 'TV/Movies Related - Entertainment'}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697121477832705',
#       'name': 'Publisher & News Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to  marketing and advertiser agencies, publishers of magazines, newspapers, blogs, books'}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '47',
#       'name': 'Brand',
#       'description': 'Brands and Companies'},
#      'entity': {'id': '1137022824931921920', 'name': 'MSNBC'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1046545033657081857',
#       'name': 'News',
#       'description': 'News'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1137022824931921920', 'name': 'MSNBC'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1196447117297905665', 'name': 'News outlets'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '30',
#       'name': 'Entities [Entity Service]',
#       'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'},
#      'entity': {'id': '781974596752842752', 'name': 'Services'}},
#     {'domain': {'id': '47',
#       'name': 'Brand',
#       'description': 'Brands and Companies'},
#      'entity': {'id': '10040666972', 'name': 'The New York Times'}},
#     {'domain': {'id': '47',
#       'name': 'Brand',
#       'description': 'Brands and Companies'},
#      'entity': {'id': '10040667002', 'name': 'The Washington Post'}},
#     {'domain': {'id': '47',
#       'name': 'Brand',
#       'description': 'Brands and Companies'},
#      'entity': {'id': '10045225402', 'name': 'Twitter'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '10040666972', 'name': 'The New York Times'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '10040667002', 'name': 'The Washington Post'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1046545033657081857',
#       'name': 'News',
#       'description': 'News'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1196447117297905665', 'name': 'News outlets'}}],
#    'id': '1614850335889305603',
#    'text': '@WallStreetSilv @nytimes @MSNBC @facebook @washingtonpost Technically, Twitter should have that label',
#    'created_at': '2023-01-16T05:01:37.000Z'},
#   {'edit_history_tweet_ids': ['1614849868396376070'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614849868396376070',
#    'text': '@budan_m 🔥',
#    'created_at': '2023-01-16T04:59:45.000Z'},
#   {'edit_history_tweet_ids': ['1614849294586241024'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614849294586241024',
#    'text': '@JohnRWoodJr @alexandrosM Sam has changed a lot, but I suppose so have we all',
#    'created_at': '2023-01-16T04:57:28.000Z'},
#   {'edit_history_tweet_ids': ['1614828000897564672'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614828000897564672',
#    'text': '@engineers_feed Nuclear is way safer than coal',
#    'created_at': '2023-01-16T03:32:52.000Z'},
#   {'edit_history_tweet_ids': ['1614821544630554624'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614821544630554624',
#    'text': '@dogeofficialceo 🤣🔥',
#    'created_at': '2023-01-16T03:07:12.000Z'},
#   {'edit_history_tweet_ids': ['1614819937209708548'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614819937209708548',
#    'text': '@Kristennetten @la_lkm @tmrohan Is this happening a lot?',
#    'created_at': '2023-01-16T03:00:49.000Z'},
#   {'edit_history_tweet_ids': ['1614819551694458880'],
#    'context_annotations': [{'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '1070710938410475525',
# ...
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '123',
#       'name': 'Ongoing News Story',
#       'description': "Ongoing News Stories like 'Brexit'"},
#      'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614780167788048385',
#    'text': '@SamTwits @alexandrosM I’m pro vaccines in general, but there’s a point where the cure/vaccine is potentially worse, if administered to the whole population, than the disease',
#    'created_at': '2023-01-16T00:22:47.000Z'},
#   {'edit_history_tweet_ids': ['1614775803644116993'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614775803644116993',
#    'text': 'Falcon Heavy Ascends https://t.co/tXZBbuoyRr',
#    'created_at': '2023-01-16T00:05:27.000Z'},
#   {'edit_history_tweet_ids': ['1614768318698893312'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '30',
#       'name': 'Entities [Entity Service]',
#       'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'},
#      'entity': {'id': '781974596752842752', 'name': 'Services'}},
#     {'domain': {'id': '47',
#       'name': 'Brand',
#       'description': 'Brands and Companies'},
#      'entity': {'id': '10045225402', 'name': 'Twitter'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614768318698893312',
#    'text': '@WallStreetSilv I do laugh a lot on Twitter haha',
#    'created_at': '2023-01-15T23:35:42.000Z'},
#   {'edit_history_tweet_ids': ['1614767219313102849'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614767219313102849',
#    'text': '@alexandrosM Sam sounds like his Ayahuasca trip hasn’t fully worn off',
#    'created_at': '2023-01-15T23:31:20.000Z'},
#   {'edit_history_tweet_ids': ['1614763835503837185'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614763835503837185',
#    'text': '@JaneidyEve It should already feel better than the past',
#    'created_at': '2023-01-15T23:17:53.000Z'},
#   {'edit_history_tweet_ids': ['1614761844010528770'],
#    'context_annotations': [{'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557696848252391426',
#       'name': 'Financial Services Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to Banks, Credit cards, Insurance, Investments, Stocks '}},
#     {'domain': {'id': '46',
#       'name': 'Business Taxonomy',
#       'description': 'Categories within Brand Verticals that narrow down the scope of Brands'},
#      'entity': {'id': '1557697333571112960',
#       'name': 'Technology Business',
#       'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}},
#     {'domain': {'id': '10',
#       'name': 'Person',
#       'description': 'Named people in the world like Nelson Mandela'},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '30',
#       'name': 'Entities [Entity Service]',
#       'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'},
#      'entity': {'id': '781974596752842752', 'name': 'Services'}},
#     {'domain': {'id': '47',
#       'name': 'Brand',
#       'description': 'Brands and Companies'},
#      'entity': {'id': '10045225402', 'name': 'Twitter'}},
#     {'domain': {'id': '65',
#       'name': 'Interests and Hobbies Vertical',
#       'description': 'Top level interests and hobbies groupings, like Food or Travel'},
#      'entity': {'id': '781974596148793345', 'name': 'Business & finance'}},
#     {'domain': {'id': '66',
#       'name': 'Interests and Hobbies Category',
#       'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'},
#      'entity': {'id': '857878777191211008',
#       'name': 'Leadership',
#       'description': 'Leadership'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '808713037230157824',
#       'name': 'Elon Musk',
#       'description': 'Elon Musk'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1091420346660470784',
#       'name': 'Tech personalities',
#       'description': 'Tech Professionals'}},
#     {'domain': {'id': '131',
#       'name': 'Unified Twitter Taxonomy',
#       'description': 'A taxonomy of user interests. '},
#      'entity': {'id': '1166406108623163392',
#       'name': 'Business personalities'}}],
#    'id': '1614761844010528770',
#    'text': 'Instagram makes people depressed &amp; Twitter makes people angry. Which is better?',
#    'created_at': '2023-01-15T23:09:59.000Z'}],
#  'meta': {'newest_id': '1615110825353838592',
#   'oldest_id': '1614761844010528770',
#   'result_count': 34}}

# %%
'''
Writing Tweets to a text file

This example shows how you can write the Tweet IDs for each Tweet obtained 
for a search result, to a text file.

Make sure to replace the file_name with the a name of your chosing.

If you wish to write other fields to the text file, make sure to adjust the script below accordingly.
'''

file_name = 'tweets.txt'

df1.to_csv(file_name, index=False, encoding='utf-8')

# If you want a different delimiter, say, tab or '\t'
# You can do:
#    df2.to_csv(file_name, index=False, encoding='utf-8', sep='\t')
