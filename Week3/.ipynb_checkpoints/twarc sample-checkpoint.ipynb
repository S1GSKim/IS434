RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 1   RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 2   Vitamin D and estrogen steroid hormones and th...
# 3   RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 4   RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 5   RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 6   RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 7   RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 8   RT @ilo: OUT NOW: World Social Protection Repo...
# 9   RT @WADeptHealth: Expiration dates have been e...
# 10  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 11  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 12  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 13  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 14  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 15  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 16  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 17  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 18  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 19  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 20  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 21  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 22  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 23  Expiration dates have been extended. Learn mor...
# 24  ‘Iedereen is negatief. Het is een soort collec...
# 25  RT @wilko_wedyn: @M_Muszalski https://t.co/30C...
# 26  @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps:...
# 27  The Technical meeting on the future of work in...
# 28  China wil covid voor altijd vergeten, al zal d...
# 29  .⁦@leenvervaeke⁩: Voor de inwoners van Wuhan i...
# 30  Vanuit Wuhan, stad van de eerste uitbraak, waa...
# 31  "Het is niet de ziekte die ons bang of boos ma...
# 32  EU-LAC Inter-regionalism during the covid-19 p...
# 33  The normative emergence of death in the Organi...
# 34  Latin American and Caribbean Regional Organiza...
# 35  Still a pragmatic tool address specific proble...
# 36  Regional Health and Economic Responses to the ...
# 37  RT @tweetastevens: 📢 Public health professiona...
# 38  The president appeared before Congress and spo...
# 39  📢 Public health professionals, \n@nccmt is loo...
# 40  RT @RudieBdeV: @Alec_Zeck @IanCopeland5 https:...
# 41  @Alec_Zeck @IanCopeland5 https://t.co/vhnyVgE6...
# 42  RT @KarenBatt_CPSU: We're hailed as “heroes'' ...
# 43  COVID-19 in Bulgaria: 47 New Cases in the Last...
# 44  RT @KarenBatt_CPSU: We're hailed as “heroes'' ...
# 45  RT @KarenBatt_CPSU: We're hailed as “heroes'' ...
# 46  RT @KarenBatt_CPSU: We're hailed as “heroes'' ...
# 47  [VROZ] Virtual girl group survival 'RE:VERSE',...
# 48  We're hailed as “heroes'' throughout Covid-19 ...
# 49  @kasleuk @LinkSis67 @fmeeus1 Anti-doctrine is ...
# 50  $COSM Cosmos Health Announces Initial Purchase...
# 51  RT @UniGroningenFEB: In one of their projects,...
# 52  RT @VozMediaUSA: Adams lifts Covid vaccine man...
# 53  Adams lifts Covid vaccine mandate that left mo...
# 54  ‘Alsof ze opeens de stekker eruit hebben gehaa...
# 55  COVID-19 in Bulgaria: 57 New Cases in the Last...
# 56  @everhuizerstijn @KAFKA_Dev Kletspraat. Ook me...
# 57  Tyrkiet 🇹🇷\n\nSINOVAC's COVID-19 vaccine, Coro...
#
#                                     referenced_tweets  \
# 0   [{'type': 'retweeted', 'id': '1623717966968676...
# 1   [{'type': 'retweeted', 'id': '1623717966968676...
# 2                                                 NaN
# 3   [{'type': 'retweeted', 'id': '1623717966968676...
# 4   [{'type': 'retweeted', 'id': '1623717966968676...
# 5   [{'type': 'retweeted', 'id': '1623717966968676...
# 6   [{'type': 'retweeted', 'id': '1623717966968676...
# 7   [{'type': 'retweeted', 'id': '1623717966968676...
# 8   [{'type': 'retweeted', 'id': '1433023917237669...
# 9   [{'type': 'retweeted', 'id': '1623727908635148...
# 10  [{'type': 'retweeted', 'id': '1623717966968676...
# 11  [{'type': 'retweeted', 'id': '1623717966968676...
# 12  [{'type': 'retweeted', 'id': '1623717966968676...
# 13  [{'type': 'retweeted', 'id': '1623717966968676...
# 14  [{'type': 'retweeted', 'id': '1623717966968676...
# 15  [{'type': 'retweeted', 'id': '1623717966968676...
# 16  [{'type': 'retweeted', 'id': '1623717966968676...
# 17  [{'type': 'retweeted', 'id': '1623717966968676...
# 18  [{'type': 'retweeted', 'id': '1623717966968676...
# 19  [{'type': 'retweeted', 'id': '1623717966968676...
# 20  [{'type': 'retweeted', 'id': '1623717966968676...
# 21  [{'type': 'retweeted', 'id': '1623717966968676...
# 22  [{'type': 'retweeted', 'id': '1623717966968676...
# 23  [{'type': 'replied_to', 'id': '162372790629482...
# 24                                                NaN
# 25  [{'type': 'retweeted', 'id': '1623717966968676...
# 26  [{'type': 'replied_to', 'id': '162371429019573...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  [{'type': 'replied_to', 'id': '162343477718457...
# 33  [{'type': 'replied_to', 'id': '162343477507457...
# 34  [{'type': 'replied_to', 'id': '162343477324193...
# 35  [{'type': 'replied_to', 'id': '162343476896794...
# 36  [{'type': 'replied_to', 'id': '162343476567540...
# 37  [{'type': 'retweeted', 'id': '1623392268206874...
# 38                                                NaN
# 39                                                NaN
# 40  [{'type': 'retweeted', 'id': '1623312308263960...
# 41  [{'type': 'replied_to', 'id': '162311475769894...
# 42  [{'type': 'retweeted', 'id': '1623102767157108...
# 43                                                NaN
# 44  [{'type': 'retweeted', 'id': '1623102767157108...
# 45  [{'type': 'retweeted', 'id': '1623102767157108...
# 46  [{'type': 'retweeted', 'id': '1623102767157108...
# 47                                                NaN
# 48                                                NaN
# 49  [{'type': 'replied_to', 'id': '162299988513699...
# 50                                                NaN
# 51  [{'type': 'retweeted', 'id': '1600052848083042...
# 52  [{'type': 'retweeted', 'id': '1622948150704226...
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56  [{'type': 'replied_to', 'id': '161937128084248...
# 57                                                NaN
#
#                                     entities.mentions  \
# 0   [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 1   [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 2   [{'start': 123, 'end': 134, 'username': 'RedeS...
# 3   [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 4   [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 5   [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 6   [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 7   [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 8   [{'start': 3, 'end': 7, 'username': 'ilo', 'id...
# 9   [{'start': 3, 'end': 16, 'username': 'WADeptHe...
# 10  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 11  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 12  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 13  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 14  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 15  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 16  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 17  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 18  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 19  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 20  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 21  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 22  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 23                                                NaN
# 24                                                NaN
# 25  [{'start': 3, 'end': 15, 'username': 'wilko_we...
# 26  [{'start': 0, 'end': 12, 'username': 'M_Muszal...
# 27  [{'start': 239, 'end': 243, 'username': 'ilo',...
# 28                                                NaN
# 29  [{'start': 2, 'end': 15, 'username': 'leenverv...
# 30  [{'start': 268, 'end': 279, 'username': 'volks...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  [{'start': 3, 'end': 17, 'username': 'tweetast...
# 38                                                NaN
# 39  [{'start': 32, 'end': 38, 'username': 'nccmt',...
# 40  [{'start': 3, 'end': 13, 'username': 'RudieBde...
# 41  [{'start': 0, 'end': 10, 'username': 'Alec_Zec...
# 42  [{'start': 3, 'end': 18, 'username': 'KarenBat...
# 43                                                NaN
# 44  [{'start': 3, 'end': 18, 'username': 'KarenBat...
# 45  [{'start': 3, 'end': 18, 'username': 'KarenBat...
# 46  [{'start': 3, 'end': 18, 'username': 'KarenBat...
# 47                                                NaN
# 48  [{'start': 178, 'end': 194, 'username': 'union...
# 49  [{'start': 0, 'end': 8, 'username': 'kasleuk',...
# 50                                                NaN
# 51  [{'start': 3, 'end': 19, 'username': 'UniGroni...
# 52  [{'start': 3, 'end': 15, 'username': 'VozMedia...
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56  [{'start': 17, 'end': 27, 'username': 'KAFKA_D...
# 57                                                NaN
#
#                                   context_annotations      geo.place_id  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2   [{'domain': {'id': '123', 'name': 'Ongoing New...  cae987165260f81f
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
# 5                                                 NaN               NaN
# 6                                                 NaN               NaN
# 7                                                 NaN               NaN
# 8                                                 NaN               NaN
# 9   [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 10                                                NaN               NaN
# 11                                                NaN               NaN
# 12                                                NaN               NaN
# 13                                                NaN               NaN
# 14                                                NaN               NaN
# 15                                                NaN               NaN
# 16                                                NaN               NaN
# 17                                                NaN               NaN
# 18                                                NaN               NaN
# 19                                                NaN               NaN
# 20                                                NaN               NaN
# 21                                                NaN               NaN
# 22                                                NaN               NaN
# 23  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 24                                                NaN               NaN
# 25                                                NaN               NaN
# 26                                                NaN               NaN
# 27  [{'domain': {'id': '66', 'name': 'Interests an...               NaN
# 28  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 29                                                NaN               NaN
# 30  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 31                                                NaN               NaN
# 32  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 33  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 34  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 35  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 36  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 37                                                NaN               NaN
# 38  [{'domain': {'id': '10', 'name': 'Person', 'de...               NaN
# 39  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 40                                                NaN               NaN
# 41                                                NaN               NaN
# 42  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 43  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 44  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 45  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 46  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 47  [{'domain': {'id': '46', 'name': 'Business Tax...               NaN
# 48  [{'domain': {'id': '29', 'name': 'Events [Enti...               NaN
# 49  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 50  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 51                                                NaN               NaN
# 52  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 53  [{'domain': {'id': '10', 'name': 'Person', 'de...               NaN
# 54  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 55  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 56  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
# 57  [{'domain': {'id': '123', 'name': 'Ongoing New...               NaN
#
#                                attachments.media_keys  in_reply_to_user_id
# 0                                                 NaN                  NaN
# 1                                                 NaN                  NaN
# 2   [3_1623849510739795973, 3_1623849510731390977,...                  NaN
# 3                                                 NaN                  NaN
# 4                                                 NaN                  NaN
# 5                                                 NaN                  NaN
# 6                                                 NaN                  NaN
# 7                                                 NaN                  NaN
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11                                                NaN                  NaN
# 12                                                NaN                  NaN
# 13                                                NaN                  NaN
# 14                                                NaN                  NaN
# 15                                                NaN                  NaN
# 16                                                NaN                  NaN
# 17                                                NaN                  NaN
# 18                                                NaN                  NaN
# 19                                                NaN                  NaN
# 20                                                NaN                  NaN
# 21                                                NaN                  NaN
# 22                                                NaN                  NaN
# 23                                                NaN             59545968
# 24                                                NaN                  NaN
# 25                                                NaN                  NaN
# 26                                                NaN           1910795154
# 27                                                NaN                  NaN
# 28                                                NaN                  NaN
# 29                                                NaN                  NaN
# 30                                                NaN                  NaN
# 31                                                NaN                  NaN
# 32                                                NaN           3129450532
# 33                                                NaN           3129450532
# 34                                                NaN           3129450532
# 35                                                NaN           3129450532
# 36                                                NaN           3129450532
# 37                                                NaN                  NaN
# 38                                                NaN                  NaN
# 39                                                NaN                  NaN
# 40                                                NaN                  NaN
# 41                                                NaN            305856022
# 42                                                NaN                  NaN
# 43                                                NaN                  NaN
# 44                                                NaN                  NaN
# 45                                                NaN                  NaN
# 46                                                NaN                  NaN
# 47                            [3_1623153575584219137]                  NaN
# 48                                                NaN                  NaN
# 49                                                NaN            767467470
# 50                                                NaN                  NaN
# 51                                                NaN                  NaN
# 52                                                NaN                  NaN
# 53                                                NaN                  NaN
# 54                                                NaN                  NaN
# 55                                                NaN                  NaN
# 56                                                NaN  1455174512966787083
# 57                            [3_1622680682974642176]                  NaN

# %%
# Let's retrieve just the text from each tweet
# Store each tweet text as a List item

tweet_text_list = df['text'].tolist()

tweet_text_list
# Out:
# ['RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'Vitamin D and estrogen steroid hormones and their immunogenetic roles in Infectious respiratory (TB and COVID-19) diseases @RedeSciELO @UFRPEOnline \nhttps://t.co/Ce9BNXSpos https://t.co/jDNiQZhYT1',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @ilo: OUT NOW: World Social Protection Report 2020-22\nDespite the unprecedented worldwide expansion of social protection during the COVI…',
#  'RT @WADeptHealth: Expiration dates have been extended. Learn more: https://t.co/epsYECt7hr\xa0\nYou can report positive self-test results onlin…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://t…',
#  "Expiration dates have been extended. Learn more: https://t.co/epsYECt7hr\xa0\nYou can report positive self-test results online at https://t.co/D6022oCCxl or 1-800-525-0127. Any COVID-19 positive test result can be reported, even if you didn't order your test from Say Yes! COVID Test",
#  '‘Iedereen is negatief. Het is een soort collectief pessimisme. Mensen hebben geen gevoel van veiligheid meer.’\nhttps://t.co/lPL8gdDeSC',
#  'RT @wilko_wedyn: @M_Muszalski https://t.co/30CCO9UZcc\n\nhttps://t.co/o92SczHFyJ\n\nhttps://t.co/TYrudSOsoU\n\nhttps://t.co/KgCEEreGQX\n\nhttps://
# %%
'''
1) Lowercasing all the letters

This step is important to make sure that all your letters are in uniform.

temp = tweet.lower()
temp
'''
# Out:
# '\n1) Lowercasing all the letters\n\nThis step is important to make sure that all your letters are in uniform.\n\ntemp = tweet.lower()\ntemp\n'

# %%
'''
2) Removing hashtags and mentions

Hashtags and mentions are common in tweets.
There are cases where you want to remove them so you only get the 
clean content of a tweet without all these elements.

You can remove these hashtags and mentions using regex.

import re

temp = re.sub("@[A-Za-z0-9_]+","", temp)
temp = re.sub("#[A-Za-z0-9_]+","", temp)
temp
'''
# Out:
# '\n2) Removing hashtags and mentions\n\nHashtags and mentions are common in tweets.\nThere are cases where you want to remove them so you only get the \nclean content of a tweet without all these elements.\n\nYou can remove these hashtags and mentions using regex.\n\nimport re\n\ntemp = re.sub("@[A-Za-z0-9_]+","", temp)\ntemp = re.sub("#[A-Za-z0-9_]+","", temp)\ntemp\n'

# %%
'''
3) Removing links

Links are usually not necessary for text processing, so it’s
better to remove them from your text.

temp = re.sub(r"http\S+", "", temp)
temp = re.sub(r"www.\S+", "", temp)
temp
'''
# Out:
# '\n3) Removing links\n\nLinks are usually not necessary for text processing, so it’s\nbetter to remove them from your text.\n\ntemp = re.sub(r"http\\S+", "", temp)\ntemp = re.sub(r"www.\\S+", "", temp)\ntemp\n'

# %%
'''
4) Removing punctuations

Depending on your needs, you may not need punctuations such as
period, comma, exclamation mark, question mark, etc.

temp = re.sub('[()!?]', ' ', temp)
temp = re.sub('\[.*?\]',' ', temp)
temp
'''
# Out:
# "\n4) Removing punctuations\n\nDepending on your needs, you may not need punctuations such as\nperiod, comma, exclamation mark, question mark, etc.\n\ntemp = re.sub('[()!?]', ' ', temp)\ntemp = re.sub('\\[.*?\\]',' ', temp)\ntemp\n"

# %%
'''
5) Filtering non-alphanumeric characters

The previous step may have removed the punctuations, including all the
non-alphanumeric characters, but just to be sure, we can remove all letters
except the alphabets (a-z) and numbers (0-9). The sign ^ below means except.

temp = re.sub("[^a-z0-9]"," ", temp)
temp
'''
# Out:
# '\n5) Filtering non-alphanumeric characters\n\nThe previous step may have removed the punctuations, including all the\nnon-alphanumeric characters, but just to be sure, we can remove all letters\nexcept the alphabets (a-z) and numbers (0-9). The sign ^ below means except.\n\ntemp = re.sub("[^a-z0-9]"," ", temp)\ntemp\n'

# %%
'''
6) Tokenization

In tokenization, you basically tokenize your text into tokens.

And what is a token? In this case, you split your text into smaller components,
for example a paragraph into a list of sentences, or a sentence into a list of words.

Library such as nltk provides functions such as word_tokenize() or sent_tokenize()
to help you with this.

However, if you just want a simple tokenizing step where you split your text 
into words into a list, then you can do it as simple as the following code.

The result will give you a list of words from your text.

temp = temp.split()
temp
'''
# Out:
# '\n6) Tokenization\n\nIn tokenization, you basically tokenize your text into tokens.\n\nAnd what is a token? In this case, you split your text into smaller components,\nfor example a paragraph into a list of sentences, or a sentence into a list of words.\n\nLibrary such as nltk provides functions such as word_tokenize() or sent_tokenize()\nto help you with this.\n\nHowever, if you just want a simple tokenizing step where you split your text \ninto words into a list, then you can do it as simple as the following code.\n\nThe result will give you a list of words from your text.\n\ntemp = temp.split()\ntemp\n'

# %%
'''
7) Stop words removal

Stop words are words that are considered unimportant to the meaning of a text.
These words may seem important to us, humans, but to machine these words may be
considered nuisance to the processing steps.

It’s also important to keep in mind that stop words are largely language-dependent.
In English, you have stop words such as for, to, and, or, in, out, etc.

Here I first defined a list of stop words in English.
Then, I match each token with each stop word.

If a token isn’t found in the list of stop words, the token gets saved,
otherwise it’s not saved. In the end, you join all the words into one text again.


stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
 
temp = [w for w in temp if not w in stopwords]
temp = " ".join(word for word in temp)
'''
# Out:
# '\n7) Stop words removal\n\nStop words are words that are considered unimportant to the meaning of a text.\nThese words may seem important to us, humans, but to machine these words may be\nconsidered nuisance to the processing steps.\n\nIt’s also important to keep in mind that stop words are largely language-dependent.\nIn English, you have stop words such as for, to, and, or, in, out, etc.\n\nHere I first defined a list of stop words in English.\nThen, I match each token with each stop word.\n\nIf a token isn’t found in the list of stop words, the token gets saved,\notherwise it’s not saved. In the end, you join all the words into one text again.\n\n\nstopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]\n \ntemp = [w for w in temp if not w in stopwords]\ntemp = " ".join(word for word in temp)\n'

# %%
'''
Text Preprocessing: From Start to Finish

I hope you understand the steps I have explained above.
Now we can combine all those lines of code into one function that we can
call and pass an argument to.

The function then returns a clean text that is ready for you to work with.

Keep in mind that the order of steps here are not absolute.
You can arrange them around depending on your text and your needs.
The code below is what I found to be the most effective on the data I
usually work with, but in case you find another pattern of data,
you can always work them out differently.
'''
import numpy as np
import re

stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
tweets = ["Get ready for #NatGeoEarthDay! Join us on 4/21 for an evening of music and celebration, exploration and inspiration https://on.natgeo.com/3t0wzQy.",
"Coral in the shallows of Aitutaki Lagoon, Cook Islands, Polynesia https://on.natgeo.com/3gkgq4Z",
"Don't miss our @reddit AMA with author and climber Mark Synnott who will be answering your questions about his historic journey to the North Face of Everest TODAY at 12:00pm ET! Start submitting your questions here: https://on.natgeo.com/3ddSkHk @DuttonBooks"]
 
results = [clean_tweet(tw) for tw in tweets]
results
# Out:
# C:\Users\hannah.kim\AppData\Local\Temp\ipykernel_932\1029021058.py:22: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['get ready join us 4 21 evening music celebration exploration inspiration',
#  'coral shallows aitutaki lagoon cook islands polynesia',
#  'dont miss our ama with author climber mark synnott who will be answering your questions about his historic journey north face everest today at 12 00pm et start submitting your questions here']

# %%
# Let's go and apply this to our own tweets
my_results = [clean_tweet(tw) for tw in tweet_text_list]
my_results
# Out:
# C:\Users\hannah.kim\AppData\Local\Temp\ipykernel_932\1029021058.py:22: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['rt',
#  'rt',
#  'vitamin d estrogen steroid hormones their immunogenetic roles infectious respiratory tb covid 19 diseases',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt out now world social protection report 2020 22 despite unprecedented worldwide expansion social protection during covi',
#  'rt expiration dates have been extended learn more you can report positive self test results onlin',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'rt',
#  'expiration dates have been extended learn more you can report positive self test results online at or 1 800 525 0127 any covid 19 positive test result can be reported even if you didnt order your test say yes covid test',
#  'iedereen is negatief het is een soort collectief pessimisme mensen hebben geen gevoel van veiligheid meer',
#  'rt',
#  'mi ej lektury na pocz tek',
#  'technical meeting future work arts entertainment sector will take place next week geneva very timely much needed discussion considering impact covid 19 had sector via',
#  'china wil covid voor altijd vergeten al zal de pandemie er nog lang en diep nagalmen de volkskrant',
#  'voor de inwoners van wuhan is het een intense periode geweest met n maand tijd lockdowns protesten het einde van het zerocovidbeleid een immense covidgolf en uiteindelijk een heropleving van de stad',
#  'vanuit wuhan stad van de eerste uitbraak waar de geschiedenis zich 3 jaar later herhaalde poging om een collectief trauma n taboe onder woorden te brengen china wil covid voor altijd vergeten al zal de pandemie er nog lang nagalmen via',
#  'het is niet de ziekte die ons bang boos maakt maar de manier waarop ermee is omgegaan',
#  'eu lac inter regionalism during covid 19 pandemic luciano bruno theodoro',
#  'normative emergence death organization american states responses covid 19 towards regional governance death marconi cl udia santos isabela agostinelli dos miranda rafael de souza nascimento',
#  'latin american caribbean regional organizations facing covid 19 pandemic mariano karina bressan regiane ferreira guilherme',
#  'still pragmatic tool address specific problems south american regionalism response covid 19 lehmann kai enno',
#  'regional health economic responses covid 19 crisis eu latin america hoffmann andrea ribeiro katsikas dimitris',
#  'rt public health professionals is looking your input their study addresses what kinds evidence resource',
#  'president appeared before congress spoke about issues such as economic crisis covid 19 war between russia ukraine voz media offers full transcript',
#  'public health professionals is looking your input their study addresses what kinds evidence resources you accessed organizations evidence sources during covid 19 pandemic response visit consent form questionnaire',
#  'rt h',
#  '',
#  'rt were hailed as heroes throughout covid 19 but many governments fail recognise our work by dumping their caps',
#  'covid 19 bulgaria 47 new cases last 24 hours',
#  'rt were hailed as heroes throughout covid 19 but many governments fail recognise our work by dumping their caps',
#  'rt were hailed as heroes throughout covid 19 but many governments fail recognise our work by dumping their caps',
#  'rt were hailed as heroes throughout covid 19 but many governments fail recognise our work by dumping their caps',
#  'virtual girl group survival re verse suggests possibility metaverse variety show after covid 19 attempts have continued incorporate it technology into variety show existing metaverse variety show was not easy receive',
#  'were hailed as heroes throughout covid 19 but many governments fail recognise our work by dumping their caps increasing our pay properly funding our public services',
#  'anti doctrine is soms de chte doctrine afhankelijk van de discussie klimaatmetingen en wetenschap bestaan al decennia lang en pakweg het ontwikkelen van een covid vaccin totaal andere discussie kreeg niet die tijd zwem jij ook elke rivier naar het rechtse oosten',
#  'cosm cosmos health announces initial purchase order with virax biolabs distribution covid 19 influenza b antigen combo rapid tests',
#  'rt one their projects assistant professor feicheng wang co authors introduce systematic way measure china',
#  'rt adams lifts covid vaccine mandate that left more than 1 700 workers without work new york',
#  'adams lifts covid vaccine mandate that left more than 1 700 workers without work new york',
#  'alsof ze opeens de stekker eruit hebben gehaald die woorden hoort longarts gerrit bosman regelmatig van pati nten met post covid ook wel long covid hun weg richting herstel is lang en vergt veel geduld zo weet ook pati nt fred meijer',
#  'covid 19 bulgaria 57 new cases last 24 hours',
#  'kletspraat ook mensen die al lang en breed covid gehad hebben moeten een prik hoe bewijs je dat iemand minder ziek wordt word toch wakker mens kom uit die enge media bubbel',
#  'tyrkiet sinovacs covid 19 vaccine coronavac har f et udvidet godkendelse til b rn p 3 r og derover det er satme klamt det her']

# %%
# importing all necessary modules

# Note that wordcloud package also provides a stop word list
# We won't be using it here - but please do explore!!!
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in my_results:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
